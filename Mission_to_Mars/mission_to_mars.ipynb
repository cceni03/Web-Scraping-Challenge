# %%
import os
from bs4 import BeautifulSoup 
from splinter import Browser
import pandas as pd
import requests
import pymongo
import time

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# URL to scrape
url = "https://mars.nasa.gov/news/?page=0&per_page=40&order=publish_date+desc%2Ccreated_at+desc&search=&category=19%2C165%2C184%2C204&blank_scope=Latest"
browser.visit(url)
time.sleep(2)

# %%
# Iterate through all slides
for x in url:
    # HTML object
    html = browser.html
    # Parse HTML with Beautiful Soup
    soup = BeautifulSoup(html, 'html.parser')
    # Retrieve all elements that contain book information
    articles = soup.find_all('li', class_='slide')[0]
    #print(articles)

    # Iterate through each article
    for article in articles:
        title = article.find('div', class_="content_title").text
        news = article.find('div', class_= 'article_teaser_body').text
        print('-----------')
        print(title)
        print(news)
        break
# Out:
# -----------
# NASA Readies Perseverance Mars Rover's Earthly Twin
# Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape.
# -----------
# NASA Readies Perseverance Mars Rover's Earthly Twin
# Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape.
# -----------
# NASA Readies Perseverance Mars Rover's Earthly Twin
# Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape.
# -----------
# NASA Readies Perseverance Mars Rover's Earthly Twin
# Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape.
# ...

# %%
# Retrieve Most Recent News Title and Paragraph
news_title = soup.find_all('div', class_='content_title')[0].text
news_p = soup.find_all('div', class_='article_teaser_body')[0].text
print(news_title)
print("------------------------------")
print(news_p)
# Out:
# Mars Now
# ------------------------------
# Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape.

# %%
# Mars Image to be Scraped
jpl_nasa_url = 'https://www.jpl.nasa.gov'
images_url = 'https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars'
browser.visit(images_url)
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
# Retrieve JPL Featured Space Image
relativeimage_path = soup.find_all('img')[3]["src"]
featuredimage_url = jpl_nasa_url + relativeimage_path
print(featuredimage_url)
# Out:
# https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA24085-640x350.jpg

# %%
# Mars Facts
mars_url = 'https://space-facts.com/mars/'
tables = pd.read_html(mars_url)
mars_df = tables[0]
mars_df.rename(columns = {0:'Fact Heading', 1:'Fact Data'}, inplace = True)
mars_df.set_index('Fact Heading', inplace = True)
mars_df
# Out:
#                                           Fact Data
# Fact Heading
# Equatorial Diameter:                       6,792 km
# Polar Diameter:                            6,752 km
# Mass:                 6.39 × 10^23 kg (0.11 Earths)
# Moons:                          2 (Phobos & Deimos)
# Orbit Distance:            227,943,824 km (1.38 AU)
# Orbit Period:                  687 days (1.9 years)
# Surface Temperature:                   -87 to -5 °C
# First Record:                     2nd millennium BC
# Recorded By:                   Egyptian astronomers

# %%
# Converting Mars DataFrame into HTML Table
mars_html = mars_df.to_html
mars_html
# Out:
# <bound method DataFrame.to_html of                                           Fact Data
# Fact Heading
# Equatorial Diameter:                       6,792 km
# Polar Diameter:                            6,752 km
# Mass:                 6.39 × 10^23 kg (0.11 Earths)
# Moons:                          2 (Phobos & Deimos)
# Orbit Distance:            227,943,824 km (1.38 AU)
# Orbit Period:                  687 days (1.9 years)
# Surface Temperature:                   -87 to -5 °C
# First Record:                     2nd millennium BC
# Recorded By:                   Egyptian astronomers>

# %%
# Mars Hemisphere
base_url = "https://astrogeology.usgs.gov/"
marshemisphere_url = "https://astrogeology.usgs.gov/search/results?q=hemisphere+enhanced&k1=target&v1=Mars"
browser.visit(marshemisphere_url)
marshemisphere_html = browser.html

# Parse HTML with Beautiful Soup
marshemisphere_soup = BeautifulSoup(marshemisphere_html, 'html.parser')

# Mars Hemisphere Images
all_marshemisphere_images = marshemisphere_soup.find_all('div', class_='collapsible results')
marshemisphere_images = all_marshemisphere_images.find_all('div', class_='item')
print(marshemisphere_images)

marshemisphere_list = []

# Iterate through each Hemisphere Article
for image in marshemisphere_images:
        try:
            href = image.a['href']
            title = image.find('img')['alt']
            href = base_url + href
            browser.visit(href)
            marshemisphere_html = browser.html
            
            #
            marshemisphere_soup = BeautifulSoup(marshemisphere_hmtl, 'html.parser')
            marshemisphere_image_url = marshemisphere_soup.find_all('div', class_='downloads')
            sample = url.a['href']
            for url in marshemisphere_image_url:
                sample_url = url.a['href']
                marshemisphere_list.append({'title': title, 'img_url': sample_url})
                break
        except:
            print("scrape complete")
print(marshemisphere_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-fe0a0e60cdc3> in <module>
#      10 # Mars Hemisphere Images
#      11 all_marshemisphere_images = marshemisphere_soup.find_all('div', class_='collapsible results')
# ---> 12 marshemisphere_images = all_marshemisphere_images.find_all('div', class_='item')
#      13 print(marshemisphere_images)
#      14
#
# ~\anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2079         """Raise a helpful exception to explain a common code fix."""
#    2080         raise AttributeError(
# -> 2081             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2082         )
#
# ...
